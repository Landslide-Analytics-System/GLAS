# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("full_dataset_v1.csv")
print(len(df))
df.head()
# Out:
# 4477
#    Unnamed: 0     id        date        lat         lon      country  \
# 0           0   9204  2016-03-03  13.979100  121.898200  Philippines
# 1           1  12369  2015-08-15  20.840400  105.734100      Vietnam
# 2           2   6842  2017-03-10  33.370552   75.193916        India
# 3           3   8580  2017-07-09  24.827676   93.518250        India
# 4           4   9452  2011-07-03  27.316700   86.500000        Nepal
#
#   fatalities injuries                type          trigger  ...  temp1  \
# 0          0        0           landslide         flooding  ...   82.0
# 1          0        0  riverbank_collapse         downpour  ...  110.0
# 2          0        0           landslide             rain  ...   67.0
# 3          0        0           landslide  continuous_rain  ...   87.0
# 4          0        0           landslide  continuous_rain  ...   67.0
#
#      air1  humidity1  wind1  precip0  temp0    air0  humidity0  wind0  slope
# ...

# %%
print(list(df.columns))
# Out:
# ['Unnamed: 0', 'id', 'date', 'lat', 'lon', 'country', 'fatalities', 'injuries', 'type', 'trigger', 'severity', 'location', 'precip35', 'temp35', 'air35', 'humidity35', 'wind35', 'precip34', 'temp34', 'air34', 'humidity34', 'wind34', 'precip33', 'temp33', 'air33', 'humidity33', 'wind33', 'precip32', 'temp32', 'air32', 'humidity32', 'wind32', 'precip31', 'temp31', 'air31', 'humidity31', 'wind31', 'precip30', 'temp30', 'air30', 'humidity30', 'wind30', 'precip29', 'temp29', 'air29', 'humidity29', 'wind29', 'precip28', 'temp28', 'air28', 'humidity28', 'wind28', 'precip27', 'temp27', 'air27', 'humidity27', 'wind27', 'precip26', 'temp26', 'air26', 'humidity26', 'wind26', 'precip25', 'temp25', 'air25', 'humidity25', 'wind25', 'precip24', 'temp24', 'air24', 'humidity24', 'wind24', 'precip23', 'temp23', 'air23', 'humidity23', 'wind23', 'precip22', 'temp22', 'air22', 'humidity22', 'wind22', 'precip21', 'temp21', 'air21', 'humidity21', 'wind21', 'precip20', 'temp20', 'air20', 'humidity20', 'wind
# ...

# %%
df.drop(columns=["Unnamed: 0", "lat", "lon", "country", "fatalities", "injuries", "type", "trigger", "location"], inplace = True)

# %%
df
# Out:
#          id        date severity  precip35  temp35   air35  humidity35  \
# 0      9204  2016-03-03    small       0.5    86.0  1017.0        84.0
# 1     12369  2015-08-15   medium       0.0   102.0  1005.0        75.0
# 2      6842  2017-03-10  unknown       0.0    73.0  1020.0        42.0
# 3      8580  2017-07-09   medium       2.3    85.0  1006.0       100.0
# 4      9452  2011-07-03   medium       2.1    77.0  1008.0        81.0
# ...     ...         ...      ...       ...     ...     ...         ...
# 4472   2697  2010-08-30   medium       7.8    85.0  1002.0        95.0
# 4473   1012  2013-07-06   medium       6.2    46.0  1014.0        99.0
# 4474  10445  2011-06-17    large       3.3    79.0  1011.0        80.0
# 4475   4938  2011-02-04   medium       0.0    94.0  1009.0        97.0
# 4476  12544  2018-06-05   medium       1.4   100.0  1012.0        97.0
#
#       wind35  precip34  temp34  ...  temp1    air1  humidity1  wind1  precip0  \
# ...

# %%
df = df[ (df['severity'] == "small") | (df['severity'] == "medium") | (df['severity'] == "large") ]
df.reset_index(inplace=True, drop=True)
df
# Out:
#          id        date severity  precip35  temp35   air35  humidity35  \
# 0      9204  2016-03-03    small       0.5    86.0  1017.0        84.0
# 1     12369  2015-08-15   medium       0.0   102.0  1005.0        75.0
# 2      8580  2017-07-09   medium       2.3    85.0  1006.0       100.0
# 3      9452  2011-07-03   medium       2.1    77.0  1008.0        81.0
# 4     10268  2015-01-18   medium       4.0   101.0  1011.0        98.0
# ...     ...         ...      ...       ...     ...     ...         ...
# 4194   2697  2010-08-30   medium       7.8    85.0  1002.0        95.0
# 4195   1012  2013-07-06   medium       6.2    46.0  1014.0        99.0
# 4196  10445  2011-06-17    large       3.3    79.0  1011.0        80.0
# 4197   4938  2011-02-04   medium       0.0    94.0  1009.0        97.0
# 4198  12544  2018-06-05   medium       1.4   100.0  1012.0        97.0
#
#       wind35  precip34  temp34  ...  temp1    air1  humidity1  wind1  precip0  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
X = np.array(df.drop(columns=["id", "date", "severity"]))
Y = OneHotEncoder(sparse = False).fit_transform(np.array(df['severity']).reshape(-1, 1),)

# %%
Y
# Out:
# array([[0., 0., 1.],
#        [0., 1., 0.],
#        [0., 1., 0.],
#        ...,
#        [1., 0., 0.],
#        [0., 1., 0.],
#        [0., 1., 0.]])

# %%
X
# Out:
# array([[5.000e-01, 8.600e+01, 1.017e+03, ..., 8.700e+01, 2.300e+01,
#         5.400e+01],
#        [0.000e+00, 1.020e+02, 1.005e+03, ..., 8.000e+01, 1.200e+01,
#         4.000e+00],
#        [2.300e+00, 8.500e+01, 1.006e+03, ..., 1.000e+02, 4.000e+00,
#         1.070e+02],
#        ...,
#        [3.300e+00, 7.900e+01, 1.011e+03, ..., 9.300e+01, 1.300e+01,
#         9.300e+01],
#        [0.000e+00, 9.400e+01, 1.009e+03, ..., 9.700e+01, 6.000e+00,
#         6.800e+01],
#        [1.400e+00, 1.000e+02, 1.012e+03, ..., 9.100e+01, 9.000e+00,
#         7.900e+01]])

# %%
from sklearn.
